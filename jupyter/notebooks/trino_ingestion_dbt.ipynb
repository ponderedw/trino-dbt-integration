# %%
import os

def run_dbt_script(dbt_script):
    project_path = '../dbt/TrinoIngestionDbt'
    target_name = 'container'
    deps_dbt_script = f'dbt deps --project-dir {project_path} --profiles-dir {project_path} -t {target_name}'
    os.system(deps_dbt_script)
    inreached_dbt_script = f'{dbt_script} --project-dir {project_path} --profiles-dir {project_path} -t {target_name}'
    os.system(inreached_dbt_script)

# %%
run_dbt_script('dbt build --select data_ingestion')
# Out:
# 20:36:58  Running with dbt=1.8.8
# 20:36:58  Warning: No packages were found in packages.yml
# 20:36:58  Warning: No packages were found in packages.yml
# 20:36:59  Running with dbt=1.8.8
# 20:37:00  Registered adapter: trino=1.8.3
# 20:37:00  Unable to do partial parsing because saved manifest not found. Starting full parse.
# 20:37:00  Found 1 model, 1 source, 445 macros
# 20:37:00
# 20:37:01  Concurrency: 1 threads (target='container')
# 20:37:01
# 20:37:01  1 of 1 START sql table model dev_test_data_ingestion.ingestion_customers ....... [RUN]
# 20:37:01  1 of 1 OK created sql table model dev_test_data_ingestion.ingestion_customers .. [CREATE TABLE (14 rows) in 0.34s]
# 20:37:01
# 20:37:01  Finished running 1 table model in 0 hours 0 minutes and 0.82 seconds (0.82s).
# 20:37:01
# 20:37:01  Completed successfully
# 20:37:01
# 20:37:01  Done. PASS=1 WARN=0 ERROR=0 SKIP=0 TOTAL=1
